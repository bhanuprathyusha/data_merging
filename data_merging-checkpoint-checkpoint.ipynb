# %%
pwd
# Out:
# 'C:\\Users\\Bhanu Prathyusha\\Desktop\\DS_ Python'

# %%
import pandas as pd

# %%
world2015 = pd.read_csv('World_Happiness_2015.csv')

# %%
world2016 = pd.read_csv('World2016.csv')
world2017 = pd.read_csv('World2017.csv')

# %%
world2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
world2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
world2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
world2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
world2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
world2015.iloc[0:4,0:4]
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522

# %%
merge1 = world2015.iloc[0:4,0:4]

# %%
merge2 = world2016.iloc[0:4,0:4]

# %%
merge3 = world2017.iloc[0:4,2:6]

# %%
pd.concat([merge1,merge3])
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Whisker.high  \
# 2      Denmark  Western Europe             3.0            7.527           NaN
# 3       Norway  Western Europe             4.0            7.522           NaN
# 4       Canada   North America             5.0            7.427           NaN
# 5      Finland  Western Europe             6.0            7.406           NaN
# First      NaN             NaN             NaN            7.537      7.594445
# 1          NaN             NaN             NaN            7.522      7.581728
# 2          NaN             NaN             NaN            7.504      7.622030
# 3          NaN             NaN             NaN            7.494      7.561772
#
#        Whisker.low  Economy..GDP.per.Capita.
# 2              NaN                       NaN
# 3              NaN                       NaN
# 4              NaN                       NaN
# 5              NaN                       NaN
# ...

# %%
merge1
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522

# %%
merge2
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498

# %%
# row wise......column wise...
# concat   merge row and column wise...
# merge    using joints...to merge...v
# pivots_table....mean of...other descriptive statistics...

# %%
# concat...
pd.concat([merge1,merge2],axis = 0)
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498

# %%
pd.concat([merge1,merge2],axis = 1)
# Out:
#        Country          Region  Happiness Rank  Happiness Score      Country  \
# 0  Switzerland  Western Europe               1            7.587      Denmark
# 1      Iceland  Western Europe               2            7.561  Switzerland
# 2      Denmark  Western Europe               3            7.527      Iceland
# 3       Norway  Western Europe               4            7.522       Norway
#
#            Region  Happiness Rank  Happiness Score
# 0  Western Europe               1            7.526
# 1  Western Europe               2            7.509
# 2  Western Europe               3            7.501
# 3  Western Europe               4            7.498

# %%
pd.concat([merge2,merge1])
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522

# %%
pd.concat([merge1,merge3],ignore_index = True) # row wise...
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4          NaN             NaN               1            7.526
# 5          NaN             NaN               2            7.509
# 6          NaN             NaN               3            7.501
# 7          NaN             NaN               4            7.498
#
#    Lower Confidence Interval  Upper Confidence Interval
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                      7.460                      7.592
# ...

# %%
pd.concat([merge1,merge3],axis = 1)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
#
#    Happiness Rank  Happiness Score  Lower Confidence Interval  \
# 0               1            7.526                      7.460
# 1               2            7.509                      7.428
# 2               3            7.501                      7.333
# 3               4            7.498                      7.421
#
#    Upper Confidence Interval
# 0                      7.592
# 1                      7.590
# 2                      7.669
# 3                      7.575

# %%
merge3
# Out:
#    Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.
# 0            7.537      7.594445     7.479556                  1.616463
# 1            7.522      7.581728     7.462272                  1.482383
# 2            7.504      7.622030     7.385970                  1.480633
# 3            7.494      7.561772     7.426227                  1.564980

# %%
world2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
world2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
world2017.rename({'Happiness.Rank':'Happiness Rank'})
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
world2017 = world2017.rename({'Happiness.Rank':'Happiness Rank'})

# %%
world2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
world2017 = world2017.rename(index = {0:'First'},columns={'Economy..GDP.per.Capita':'GDP','Happiness.Rank':'Happiness Rank','Happiness.Score':'Happiness Score'})

# %%
world2017
# Out:
#                         Country  Happiness Rank  Happiness Score  \
# First                    Norway               1            7.537
# 1                       Denmark               2            7.522
# 2                       Iceland               3            7.504
# 3                   Switzerland               4            7.494
# 4                       Finland               5            7.469
# ...                         ...             ...              ...
# 150                      Rwanda             151            3.471
# 151                       Syria             152            3.462
# 152                    Tanzania             153            3.349
# 153                     Burundi             154            2.905
# 154    Central African Republic             155            2.693
#
#        Whisker.high  Whisker.low  Economy..GDP.per.Capita.    Family  \
# First      7.594445     7.479556                  1.616463  1.533524
# ...

# %%
# merge function...

# %%
pd.merge(left = merge1,right = merge3, how = 'outer')
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Whisker.high  \
# 0  Switzerland  Western Europe             1.0            7.587           NaN
# 1      Iceland  Western Europe             2.0            7.561           NaN
# 2      Denmark  Western Europe             3.0            7.527           NaN
# 3       Norway  Western Europe             4.0            7.522           NaN
# 4          NaN             NaN             NaN            7.537      7.594445
# 5          NaN             NaN             NaN            7.522      7.581728
# 6          NaN             NaN             NaN            7.504      7.622030
# 7          NaN             NaN             NaN            7.494      7.561772
#
#    Whisker.low  Economy..GDP.per.Capita.
# 0          NaN                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4     7.479556                  1.616463
# ...

# %%
pd.merge(left = merge1,right = merge3, how = 'inner')
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Whisker.high, Whisker.low, Economy..GDP.per.Capita.]
# Index: []

# %%
pd.merge(left = merge1,right = merge3, how = 'left')
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Whisker.high  \
# 0  Switzerland  Western Europe               1            7.587           NaN
# 1      Iceland  Western Europe               2            7.561           NaN
# 2      Denmark  Western Europe               3            7.527           NaN
# 3       Norway  Western Europe               4            7.522           NaN
#
#    Whisker.low  Economy..GDP.per.Capita.
# 0          NaN                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN

# %%
pd.merge(left = merge1,right = merge2, how = 'outer',on = 'Country')
# Out:
#        Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0  Switzerland  Western Europe                 1              7.587
# 1      Iceland  Western Europe                 2              7.561
# 2      Denmark  Western Europe                 3              7.527
# 3       Norway  Western Europe                 4              7.522
#
#          Region_y  Happiness Rank_y  Happiness Score_y
# 0  Western Europe                 2              7.509
# 1  Western Europe                 3              7.501
# 2  Western Europe                 1              7.526
# 3  Western Europe                 4              7.498

# %%
merge1 = world2015.iloc[2:6,0:4]

# %%
pd.merge(left = merge1,right = merge2, how = 'outer',on = 'Country')
# Out:
#        Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0      Denmark  Western Europe               3.0              7.527
# 1       Norway  Western Europe               4.0              7.522
# 2       Canada   North America               5.0              7.427
# 3      Finland  Western Europe               6.0              7.406
# 4  Switzerland             NaN               NaN                NaN
# 5      Iceland             NaN               NaN                NaN
#
#          Region_y  Happiness Rank_y  Happiness Score_y
# 0  Western Europe               1.0              7.526
# 1  Western Europe               4.0              7.498
# 2             NaN               NaN                NaN
# 3             NaN               NaN                NaN
# 4  Western Europe               2.0              7.509
# 5  Western Europe               3.0              7.501

# %%
pd.merge(left = merge1,right = merge2, how = 'inner',on = 'Country')
# Out:
#    Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0  Denmark  Western Europe                 3              7.527
# 1   Norway  Western Europe                 4              7.522
#
#          Region_y  Happiness Rank_y  Happiness Score_y
# 0  Western Europe                 1              7.526
# 1  Western Europe                 4              7.498

# %%
pd.merge(left = merge1,right = merge2, how = 'outer',on = 'Country',suffixes=('_2015','_2016'))
# Out:
#        Country     Region_2015  Happiness Rank_2015  Happiness Score_2015  \
# 0      Denmark  Western Europe                  3.0                 7.527
# 1       Norway  Western Europe                  4.0                 7.522
# 2       Canada   North America                  5.0                 7.427
# 3      Finland  Western Europe                  6.0                 7.406
# 4  Switzerland             NaN                  NaN                   NaN
# 5      Iceland             NaN                  NaN                   NaN
#
#       Region_2016  Happiness Rank_2016  Happiness Score_2016
# 0  Western Europe                  1.0                 7.526
# 1  Western Europe                  4.0                 7.498
# 2             NaN                  NaN                   NaN
# 3             NaN                  NaN                   NaN
# 4  Western Europe                  2.0                 7.509
# 5  Western Europe                  3.0                 7.501

# %%
pd.concat([merge1,merge2,merge3])
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 2          Denmark  Western Europe             3.0            7.527
# 3           Norway  Western Europe             4.0            7.522
# 4           Canada   North America             5.0            7.427
# 5          Finland  Western Europe             6.0            7.406
# 0          Denmark  Western Europe             1.0            7.526
# 1      Switzerland  Western Europe             2.0            7.509
# 2          Iceland  Western Europe             3.0            7.501
# 3           Norway  Western Europe             4.0            7.498
# First          NaN             NaN             NaN            7.537
# 1              NaN             NaN             NaN            7.522
# 2              NaN             NaN             NaN            7.504
# 3              NaN             NaN             NaN            7.494
#
#        Whisker.high  Whisker.low  Economy..GDP.per.Capita.
# ...

# %%
df_row = pd.concat([merge1,merge3,merge2])
df_row
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 0          NaN             NaN             NaN              NaN
# 1          NaN             NaN             NaN              NaN
# 2          NaN             NaN             NaN              NaN
# 3          NaN             NaN             NaN              NaN
# 0      Denmark  Western Europe             1.0            7.526
# 1  Switzerland  Western Europe             2.0            7.509
# 2      Iceland  Western Europe             3.0            7.501
# 3       Norway  Western Europe             4.0            7.498
#
#    Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.
# ...

# %%
pd.concat([merge1,merge2,merge3],ignore_index = True)
# Out:
#         Country          Region  Happiness Rank  Happiness Score  \
# 0   Switzerland  Western Europe             1.0            7.587
# 1       Iceland  Western Europe             2.0            7.561
# 2       Denmark  Western Europe             3.0            7.527
# 3        Norway  Western Europe             4.0            7.522
# 4       Denmark  Western Europe             1.0            7.526
# 5   Switzerland  Western Europe             2.0            7.509
# 6       Iceland  Western Europe             3.0            7.501
# 7        Norway  Western Europe             4.0            7.498
# 8           NaN             NaN             NaN              NaN
# 9           NaN             NaN             NaN              NaN
# 10          NaN             NaN             NaN              NaN
# 11          NaN             NaN             NaN              NaN
#
#     Happiness.Score  Whisker.high  Whisker.low  Economy..GDP.per.Capita.
# ...

# %%
table_1 = pd.concat([merge1,merge2,merge1],ignore_index = True);table_1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4      Denmark  Western Europe               1            7.526

# %%
table_1.pivot_table(index = 'Region',values = 'Happiness Score')
# Out:
#                 Happiness Score
# Region
# Western Europe         7.535667

# %%
world2015.pivot_table(index = 'Region',values = 'Happiness Score')
# Out:
#                                  Happiness Score
# Region
# Australia and New Zealand               7.285000
# Central and Eastern Europe              5.332931
# Eastern Asia                            5.626167
# Latin America and Caribbean             6.144682
# Middle East and Northern Africa         5.406900
# North America                           7.273000
# Southeastern Asia                       5.317444
# Southern Asia                           4.580857
# Sub-Saharan Africa                      4.202800
# Western Europe                          6.689619

# %%
fortune = pd.read_csv('f500.csv')

# %%
fortune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
fortune.pivot_table(index = 'industry',values = 'revenues').head(10)
# Out:
#                                      revenues
# industry
# Aerospace and Defense            46985.214286
# Airlines                         35012.000000
# Apparel                          37244.500000
# Banks: Commercial and Savings    55455.686275
# Beverages                        36937.333333
# Building Materials, Glass        34958.750000
# Chemicals                        39618.857143
# Computer Software                48921.333333
# Computers, Office Equipment      61296.000000
# Construction and Farm Machinery  32590.500000

# %%
fortune.pivot_table(index = 'sector',values = 'profits' ).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sector'>

# %%
dir(pd.DataFrame.plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_kind_aliases',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
# pivot table

# %%
fortune.pivot_table(index = 'sector',values = 'profits' ).plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='sector'>

# %%
fortune.pivot_table(index = 'sector',values = 'profits' ).plot(kind = 'pie',subplots = True,figsize = (15,25))
# Out:
# array([<AxesSubplot:ylabel='profits'>], dtype=object)

# %%
fortune.pivot_table(index = 'sector',values = 'profits' ).plot(kind = 'pie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-b41ab33c6e27> in <module>
# ----> 1 fortune.pivot_table(index = 'sector',values = 'profits' ).plot(kind = 'pie')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     898             if isinstance(data, ABCDataFrame):
#     899                 if y is None and kwargs.get("subplots") is False:
# --> 900                     raise ValueError(
#     901                         f"{kind} requires either y column or 'subplots=True'"
#     902                     )
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
world2015['sector'].plot(kind = 'pie')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sector'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ab8d3043fc5e> in <module>
# ...

# %%
plt.scatter(fortune['profits'],fortune['sector'])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(fortune['profits'],fortune['revenues'])

# %%
plt.scatter(fortune['industry'],fortune['profits'])

# %%
fortune['industry'].unique()
# Out:
# array(['General Merchandisers', 'Utilities', 'Petroleum Refining',
#        'Motor Vehicles and Parts',
#        'Insurance: Property and Casualty (Stock)',
#        'Computers, Office Equipment', 'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care',
#        'Health Care: Pharmacy and Other Services',
#        'Electronics, Electrical Equip.', 'Mining, Crude-Oil Production',
#        'Telecommunications', 'Diversified Financials',
#        'Banks: Commercial and Savings', 'Engineering, Construction',
#        'Insurance: Life, Health (stock)',
#        'Internet Services and Retailing', 'Industrial Machinery',
#        'Food and Drug Stores', 'Trading', 'Specialty Retailers',
#        'Aerospace and Defense', 'Energy', 'Food Consumer Products',
#        'Computer Software', 'Information Technology Services',
#        'Network and Other Communications Equipment',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
# ...

# %%
fortune[fortune['industry'] == 'Trading']
# Out:
#                                    company  rank  revenues  revenue_change  \
# 53                         Trafigura Group    54     98098             0.9
# 115                               Marubeni   116     65792             8.2
# 128                            Tewoo Group   129     63324            -1.4
# 135                                  COFCO   136     61265            -5.0
# 142                         Sinochem Group   143     59533            -1.9
# 144                             Mitsubishi   145     59303             2.8
# 204                            Noble Group   205     46528           -30.3
# 214                                 Itochu   215     44654             5.5
# 248                                 Mitsui   249     40275             1.6
# 281                               Sumitomo   282     36888            10.4
# 294                         Rajesh Exports   295     36114            43.1
# ...

# %%
a_1 = fortune[fortune['industry'] == 'Trading']

# %%
a_2 = fortune[fortune['industry'] == 'Energy']

# %%
a_1 & a_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-79e959f7f12f> in <module>
# ----> 1 a_1 & a_2
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     649         if isinstance(other, ABCDataFrame):
#     650             # Another DataFrame
# --> 651             new_data = self._combine_frame(other, na_op, fill_value)
#     652
#     653         elif isinstance(other, ABCSeries):
#
# ...

# %%
pd.concat([a_1,a_2])
# Out:
#                                    company  rank  revenues  revenue_change  \
# 53                         Trafigura Group    54     98098             0.9
# 115                               Marubeni   116     65792             8.2
# 128                            Tewoo Group   129     63324            -1.4
# 135                                  COFCO   136     61265            -5.0
# 142                         Sinochem Group   143     59533            -1.9
# 144                             Mitsubishi   145     59303             2.8
# 204                            Noble Group   205     46528           -30.3
# 214                                 Itochu   215     44654             5.5
# 248                                 Mitsui   249     40275             1.6
# 281                               Sumitomo   282     36888            10.4
# 294                         Rajesh Exports   295     36114            43.1
# ...

# %%
a_3 = pd.concat([a_1,a_2])

# %%
plt.scatter(a_3['industry'],a_3['profits'])

# %%
plt.figure(figsize = (10,10))
plt.scatter(a_3['industry'],a_3['profits'])

# %%
a_1 = fortune['industry'] == 'Trading'
a_1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: industry, Length: 500, dtype: bool

# %%
a_2 = fortune['industry'] == 'Energy'
a_2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: industry, Length: 500, dtype: bool

# %%
a_4 = fortune[a_1]  fortune[a_2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-bbf170c1877d> in <module>
# ----> 1 fortune[a_1] & fortune[a_2]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     649         if isinstance(other, ABCDataFrame):
#     650             # Another DataFrame
# --> 651             new_data = self._combine_frame(other, na_op, fill_value)
#     652
# ...

# %%
plt.hist(fortune['profits'],bins = 20,histtype = 'stepfilled',orientation = 'horizontal')
plt.xlabel('profits')
plt.ylabel('counts')
plt.title('my graph')
# Out:
# Text(0.5, 1.0, 'my graph')
